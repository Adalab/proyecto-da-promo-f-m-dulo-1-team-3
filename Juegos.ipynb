# %% [markdown]
# ### El juego PIEDRA, PAPEL o TIJERA

# %% [markdown]
# - Es un juego de azar
# - 2 jugadores y 3 opciones:
#     - Ambos jugadores, eligen a la vez una de las tres opciones: piedra, papel o tijera
#     - Cada opción tiene una relación de victoria diferente:
#         - piedra vence a tijera
#         - tijera vence a papel
#         - papel vence a piedra
#     - Aquel jugador que llegue antes a 3 puntos, gana el juego

# %%
import random

def jugar_ppt():

    print('\n¡¡¡¡ Bienvenid@ al juego de piedra🪨, papel🗒️ o tijera✂️ !!!!\n', flush= True)
    nombre_jugador = input('¿Cómo quieres qué te llamemos?')
    print(f'Hola {nombre_jugador}. Comencemos a jugar. Vas a jugar contra el PC.\n Para ganarle tendrás que acumular tres puntos\n', flush= True)

    opciones= ['piedra', 'papel', 'tijera']
    puntos_jugador = 0
    puntos_pc = 0

    while puntos_jugador < 3 and puntos_pc < 3:

        jugador_usuario = input(f'Ingrese una opción entre las siguientes: {opciones}').lower()
        

        while jugador_usuario not in opciones: 
            print(f"La opción: {jugador_usuario} es una opcion equivocada. Ingrese una opción válida: {opciones}", flush= True)
            print ("___________________\n", flush= True)
            jugador_usuario = input(f'Ingrese una opción válida: {opciones}').lower() 

        jugador_pc = random.choice(opciones) 
        print (f"{nombre_jugador} eligió {jugador_usuario} y el PC {jugador_pc}", flush= True)
        
        if jugador_usuario == jugador_pc:
            print ("EMPATE", flush= True) 

        if (jugador_usuario == 'piedra' and jugador_pc == 'tijera') or (jugador_usuario == 'tijera' and jugador_pc == 'papel') or (jugador_usuario == 'papel' and jugador_pc == 'piedra'):
            print (f"GANA {nombre_jugador}", flush= True)
            puntos_jugador += 1

        if (jugador_usuario == 'piedra' and jugador_pc == 'papel') or (jugador_usuario == 'tijera' and jugador_pc == 'piedra') or (jugador_usuario == 'papel' and jugador_pc == 'tijera'):
            print ("GANA EL PC", flush= True)
            puntos_pc += 1

        print (f"Puntos {nombre_jugador}: {puntos_jugador} - Puntos PC: {puntos_pc}", flush= True)
        print ("________________________\n", flush= True)
        
    if puntos_jugador == 3 :
        print ("ENHORABUENA!! Has ganado la partida!!", flush= True)

    if puntos_pc == 3 :
        print ("Lo sentimos, has perdido la partida! Vuelve a intentarlo.", flush= True)

jugar_ppt()
automatizar = input("quieres volver a jugar?: Y/N").upper()
while automatizar == "Y":
    print()
    jugar_ppt()
    automatizar = input("quieres volver a jugar?: Y/N").upper()

if automatizar != "Y":
    print(flush = True)
    print("😊 BYE BYE 😊")
# Out:
# ¡¡¡¡ Bienvenid@ al juego de piedra🪨, papel🗒️ o tijera✂️ !!!!
#
# Hola Elena. Comencemos a jugar. Vas a jugar contra el PC.
#  Para ganarle tendrás que acumular tres puntos
#
# Elena eligió piedra y el PC piedra
# EMPATE
# Puntos Elena: 0 - Puntos PC: 0
# ________________________
#
# Elena eligió papel y el PC tijera
# GANA EL PC
# Puntos Elena: 0 - Puntos PC: 1
# ________________________
#
# Elena eligió papel y el PC papel
# EMPATE
# Puntos Elena: 0 - Puntos PC: 1
# ________________________
#
# Elena eligió tijera y el PC piedra
# GANA EL PC
# Puntos Elena: 0 - Puntos PC: 2
# ________________________
#
# Elena eligió tijera y el PC tijera
# EMPATE
# Puntos Elena: 0 - Puntos PC: 2
# ________________________
#
# Elena eligió piedra y el PC piedra
# EMPATE
# Puntos Elena: 0 - Puntos PC: 2
# ________________________
#
# Elena eligió papel y el PC tijera
# GANA EL PC
# Puntos Elena: 0 - Puntos PC: 3
# ________________________
#
# Lo sentimos, has perdido la partida! Vuelve a intentarlo.
#
#
# ¡¡¡¡ Bienvenid@ al juego de piedra🪨, papel🗒️ o tijera✂️ !!!!
#
# Hola Juan. Comencemos a jugar. Vas a jugar contra el PC.
#  Para ganarle tendrás que acumular tres puntos
#
# Juan eligió piedra y el PC papel
# GANA EL PC
# Puntos Juan: 0 - Puntos PC: 1
# ________________________

# %% [markdown]
# ### El juego del AHORCADO

# %% [markdown]
# - Es un juego de adivinanza
# - 2 jugadores:
#     - Jugador 1 elige una palabra
#     - Jugador 2 debe adivinarla letra por letra. Cuenta con número limitado de oportunidades.
# - 2 opciones:
#     - Jugador 2 da una letra incorrecta. Por cada letra, se dibuja una parte del cuerpo del ahorcado
#         - Si el dibujo del personaje del ahorcado se completa antes de adivinar la palabra, Jugador 2 pierde el juego
#     - Jugador 2 adivina todas las letras de la palabra antes de que se complete el dibujo del personaje del ahorcado, gana el juego

# %%
# Para mejorar la visualización del juego, realizamos un dibujo ddel personaje del ahorcado.
# Creamos la función horca que permitirá mostrar en pantalla la parte del muñeqco de acuerdo a las vidas restartes al jugador 2

def horca(vidas):

    print("   _______   ",flush = True)
    print(" |/       |  ",flush = True)
    if vidas <=7: 
        print(" |       (_)",flush= True)
    if vidas <=6: 
        print(" |        |",flush= True)
    else:
        print(" |           ",flush= True)
    if vidas <=5:
        print(" |       \|/",flush= True)
    else:
        print(" |           ",flush= True)
    if vidas <=4:
        print(" |        |",flush= True)
    else:
        print(" |           ",flush= True)  
    if vidas <=3:
        print(" |        |",flush= True)
    else:
        print(" |          ",flush= True)    
    if vidas ==2:
        print(" |       /  ",flush= True)      
    elif vidas <=1:
        print(" |       / \ ",flush= True)
    else:
        print(" |           ",flush= True)
    
    if vidas == 0:
        print(flush= True)
        print("GAME OVER! 🙃 ",flush= True)

horca(0)
# Out:
#    _______
#  |/       |
#  |       (_)
#  |        |
#  |       \|/
#  |        |
#  |        |
#  |       / \
#
# GAME OVER! 🙃

# %%
import random
# definimos horca, para que si hay ahorcado vaya apareciendo

def jugar_ahorcado():
    
    opciones = ["melocoton", "tomate", "guayaba", "mandarina", "pomelo", "albaricoque", "frambuesa", "mangostino", "guanabana", "durian", "carambola", "nispero"]
    secreta = random.choice(opciones)

    secreta_ = list(secreta)                            
    longitud = len(secreta_)
    tablero_ = list ("_" * len(secreta_)) # Crear el tablero (ocultar palabra secreta)
    print(f"\n¡¡¡¡ Bienvenid@ al juego del ahorcado!!!!\n ARE U READY? \n Adivina la fruta. Tu tablero tiene {longitud} caracteres: {tablero_}",flush = True)
    print()
    print(" Si fallas, irá apareciendo un ahorcado.Tu misión es adivinar la palabra ¡sin ahorcarte! 🥵 ")

    respuesta = "".join(tablero_)  

    vidas = 8 

    horca(vidas)  

    while respuesta != secreta and vidas > 0:

        j2 = input ("Incluye una letra para adivinar la palabra secreta").lower() # Preguntamos al usuario una letra para adivinar la palabra secreta
            
        if j2 in secreta_:
            print (f"\nJUGADA:\nLa letra elegida es *** {j2} ***. Has acertado. Vuelve a insertar otra letra\n")
            print (f"Te quedan {vidas} vidas\n")
            for index, i in enumerate(secreta_):
                if j2 == i:
                    tablero_[index] = i
            respuesta = "".join(tablero_)    #Lo indexamos al nivel del for para que me printe el tablero una vez finalize de iterar el "for"
            print (tablero_,flush = True)    
                        
        else:   # todos los otros casos donde j2 no está en secreta

            # Aquí, con cada fallo, se resta un intento
            vidas -= 1 
                          
            if vidas == 0:
                print(f"😓 {vidas} vidas. ¡AHORCADO! 😵")
                horca(vidas)

            elif vidas == 1:
                print(f"😓 {vidas} vidas. Ten cuidado, la soga aprieta❗",flush= True)
                horca(vidas)    
                
            else:
                #print ("Prueba otra letra",flush = True)
                print(f"Prueba otra letra. Te quedan {vidas} vidas",flush= True) 
                horca(vidas)  

    if respuesta == secreta:
        print(f"¡¡¡Felicidades!!! La palabra secreta era {secreta}. Has acabado con {vidas} vidas",flush = True)

 
 #lo hacemos función para que empiece directamente
jugar_ahorcado()
automatizar = input("quieres volver a jugar?: Y/N").upper()
while automatizar == "Y":
    print()
    jugar_ahorcado()
    automatizar = input("quieres volver a jugar?: Y/N").upper()

if automatizar != "Y":
    print(flush = True)
    print("😊 BYE BYE 😊")
# Out:
# ¡¡¡¡ Bienvenid@ al juego del ahorcado!!!!
#  ARE U READY?
#  Adivina la fruta. Tu tablero tiene 10 caracteres: ['_', '_', '_', '_', '_', '_', '_', '_', '_', '_']
#
#  Si fallas, irá apareciendo un ahorcado.Tu misión es adivinar la palabra ¡sin ahorcarte! 🥵
#    _______
#  |/       |
#  |
#  |
#  |
#  |
#  |
#
# JUGADA:
# La letra elegida es *** o ***. Has acertado. Vuelve a insertar otra letra
#
# Te quedan 8 vidas
#
# ['_', '_', '_', '_', 'o', '_', '_', '_', '_', 'o']
#
# JUGADA:
# La letra elegida es *** g ***. Has acertado. Vuelve a insertar otra letra
#
# Te quedan 8 vidas
#
# ['_', '_', '_', 'g', 'o', '_', '_', '_', '_', 'o']
#
# JUGADA:
# La letra elegida es *** m ***. Has acertado. Vuelve a insertar otra letra
#
# Te quedan 8 vidas
#
# ['m', '_', '_', 'g', 'o', '_', '_', '_', '_', 'o']
#
# JUGADA:
# La letra elegida es *** a ***. Has acertado. Vuelve a insertar otra letra
#
# Te quedan 8 vidas
#
# ['m', 'a', '_', 'g', 'o', '_', '_', '_', '_', 'o']
#
# JUGADA:
# La letra elegida es *** n ***. Has acertado. Vuelve a insertar otra letra
#
# Te quedan 8 vidas
#
# ['m', 'a', 'n', 'g', 'o', '_', '_', '_', 'n', 'o']
#
# JUGADA:
# La letra elegida es *** s ***. Has acertado. Vuelve a insertar otra letra
#
# Te quedan 8 vidas
#
# ['m', 'a', 'n', 'g', 'o', 's', '_', '_', 'n', 'o']
#
# JUGADA:
# La letra elegida es *** t ***. Has acertado. Vuelve a insertar otra letra
#
# Te quedan 8 vidas
#
# ['m', 'a', 'n', 'g', 'o', 's', 't', '_', 'n', 'o']
#
# JUGADA:
# La letra elegida es *** i ***. Has acertado. Vuelve a insertar otra letra
#
# Te quedan 8 vidas
#
# ['m', 'a', 'n', 'g', 'o', 's', 't', 'i', 'n', 'o']
# ¡¡¡Felicidades!!! La palabra secreta era mangostino. Has acabado con 8 vidas
#
#
# ¡¡¡¡ Bienvenid@ al juego del ahorcado!!!!
#  ARE U READY?
#  Adivina la fruta. Tu tablero tiene 9 caracteres: ['_', '_', '_', '_', '_', '_', '_', '_', '_']
#
#  Si fallas, irá apareciendo un ahorcado.Tu misión es adivinar la palabra ¡sin ahorcarte! 🥵
#    _______
#  |/       |
#  |
#  |
#  |
#  |
#  |

# %% [markdown]
# ### El juego del TIC TAC TOE

# %% [markdown]
# - Es un juego de estrategia
# - 2 jugadores
# - Estrategia:
#     - En una cuadrícula de 3 x 3, cada jugador por turnos, coloca una "X" o una "O"
#     - El jugador que logre tener 3 símbolos iguales en una fila (horizontal, vertical o diagonal) antes que el oponente gana el juego
#     - El juego termina en empate si la cuadrícula se llena y ningún jugador ha locrado crear una línea de tres simbolos iguales
